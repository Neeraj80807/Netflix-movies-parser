# %%
import json
import requests
import pandas as pd
import os 
from bs4 import BeautifulSoup

# %%
def get_titles_info(title_id: str):
    title_info_dict = {
        "title": "",
        "overview": "",
        "genres": [],
        "cast": [],
        "content_is": [],
        "subtitles": [],
        "audio": [],
    }

    request_url = f"https://www.netflix.com/title/{title_id}"
    response = requests.get(
        request_url, 
        # verify=False
    )
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    if soup:
        title_h1 = soup.find("h1", class_="title-title")
        if title_h1:
            title_info_dict.update({
                "title": title_h1.text
            })

        overview_div = soup.find("div", class_="title-info-synopsis")
        if overview_div:
            title_info_dict.update({            
                "overview": overview_div.text
            })

        genre_div = soup.find("div", "more-details-cell cell-genres")
        if genre_div:
            title_info_dict.update({
                "genres": [spn.text.replace(',', '').strip() for spn in genre_div.findAll('span')],
            })
            

        cast_div = soup.find("div", "more-details-cell cell-cast")
        if cast_div:
            title_info_dict.update({
                "cast": [spn.text.replace(',', '').strip() for spn in cast_div.findAll('span')]
            })


        content_mood_div = soup.find("div", "more-details-cell cell-mood-tag")
        if content_mood_div:
            title_info_dict.update({
                "content_is": [spn.text.replace(',', '').strip() for spn in content_mood_div.findAll('span')],
            })

        subtitles_div = soup.find("div", "more-details-cell cell-subtitle")
        if subtitles_div:
            title_info_dict.update({
                "subtitles": [spn.text.replace(',', '').strip() for spn in subtitles_div.findAll('span')],
            })

        audio_div = soup.find("div", "more-details-cell cell-audio")
        if subtitles_div:
            title_info_dict.update({
                "audio": [spn.text.replace(',', '').strip() for spn in audio_div.findAll('span')],
            })

    return title_info_dict

# %%
def request_netflix_titles(
        params,
        cookies, 
        headers,
        genre_id = "34399",
        from_ix = 0,
        to_ix = 100,
    ):

    genre_item_summ_path = f'["genres",{genre_id},"az",{{"from":{from_ix},"to":{to_ix}}},"itemSummary"]'
    genre_item_ref_summ_path = f'["genres",{genre_id},"az",{{"from":{from_ix},"to":{to_ix}}},"reference",["availability","episodeCount","inRemindMeList","queue","summary"]]'
    data = {
        'path': [
            genre_item_summ_path,
            genre_item_ref_summ_path,
        ]
    }

    response = requests.post(
        'https://www.netflix.com/nq/website/memberapi/vc63e5850/pathEvaluator',
        params=params,
        cookies=cookies,
        headers=headers,
        data=data,
        # verify=False
    )

    print(f"fetch status code --> {response.status_code}")
    return response

# %%
def process_titles_data(genre_id, summary_data):
    title_info_list = []

    for ix, item_summ in summary_data["jsonGraph"]["genres"][genre_id]['az'].items():
        title_info_dict = {}

        if not item_summ["itemSummary"].get("value"):
            print("No data is present, stopping here")
            break

        item_summ_val = item_summ["itemSummary"]["value"]

        print(f"processing title {int(ix)+1}: id -> {item_summ_val['id']}")

        misc_title_info_dict = get_titles_info(str(item_summ_val["id"]))

        title_info_dict.update({
            "id": str(item_summ_val["id"]),
            "title": item_summ_val["title"],
            "type": item_summ_val["type"],
            "release_year": item_summ_val["releaseYear"],
            "runtime": item_summ_val.get("infoDensityRuntime"),
            "backdrop_path": item_summ_val["boxArt"]["url"],
            "made_by_netflix": item_summ_val["isOriginal"],
            "maturity_rating": item_summ_val["maturity"]["rating"]["value"],
            "maturity_warning": item_summ_val["maturity"]["rating"]["maturityDescription"],
            "maturity_rating_reason": [ix for ix in item_summ_val["maturity"]["rating"]["specificRatingReason"].split(', ')],
            "maturity_rating_board": item_summ_val["maturity"]["rating"]["board"],
        })

        title_info_dict = {**title_info_dict, **misc_title_info_dict}

        title_info_list.append(title_info_dict)

    return title_info_list

# %%
def main():

    from_ix = 1001
    to_ix = 2000
    genre_id = "34399"
    
    params = {
        'webp': 'true',
        'drmSystem': 'widevine',
        'isVolatileBillboardsEnabled': 'true',
        'routeAPIRequestsThroughFTL': 'false',
        'hasVideoMerchInBob': 'true',
        'hasVideoMerchInJaw': 'true',
        'falcor_server': '0.1.0',
        'withSize': 'true',
        'materialize': 'true',
        'original_path': '/shakti/mre/pathEvaluator',
    }

    cookies = {
        'SecureNetflixId': 'v%3D2%26mac%3DAQEAEQABABSso5AdAyc6d1rLm-N-ww2pmkw_gZ-MUSc.%26dt%3D1697065093678',
        'NetflixId': 'v%3D2%26ct%3DBQAOAAEBEPpZZEBgGGyA-6R91KRsj5uBwKBSBq3roimqQ-myMTBpr5EOJscSEGN-imXJuk_pqxAWCmWnIHItBFFjdOCphMGRG5YI_Dehl-jMpEtCC2tdaALH-LRJCC2qk1G-bJBQFPjBqDn_NhaxZ5No9iAXvoF7G6--GxfBfRpoiYi3WWrHpvdYnO19VZaiEQFUC7jydWYOK1AmnMK2gzx71-_Xy6S2qBoog9ro7SfWLyjBY7V-sgIf_h0Ax4NhUbaCj_saQntQ7FQ7v3u9YoH88cnboovO1Rhclb_hT0XpxaQu5sqkzzi_yba164AtFZv7Mrhv6bPNNuLiIaWCHlgLCh9VRQc24IajbuQSNL2r5iG8CH-T2_UGcCjaSNfwK8msk7_qzmfxwIAHGl3NGEXtdPWY31599cSYqUBpHKZqEt6dk6FHvLldaVY6iJdJDmAxQkf3DTi1rNx5VFzZR_kEzq7uj7OLKx1EK1WA1u344Is_m1b_G_U6MudCr4kuDW5lzrF0V0yrie-45ydG7k7U2Ky9LQC0WZCt1xF-WDx3X_u9Vh1LiywBNo3jGFgI00NxeEXk_6OWGUDEaKCFKbh2hNZxv8FeG68qwHUvTyYQrMKv2n0yeAI.%26bt%3Ddbl%26ch%3DAQEAEAABABRaung3lxsP7zP6KpvmzVirkNLdm8L31PE.%26mac%3DAQEAEAABABTNJh-SZrVtr2uOWNrPU1LpO1YHsE8ElEM.',
        'profilesNewSession': '0'
    }

    headers = {
        'authority': 'www.netflix.com',
        'accept': '/',
        'accept-language': 'en-GB,en;q=0.7',
        'content-type': 'application/x-www-form-urlencoded',
    }

    response = request_netflix_titles(
        params=params,
        cookies=cookies, 
        headers=headers, 
        from_ix=from_ix, 
        to_ix=to_ix,
    )
    
    if response.status_code == 200:
        summary_data = response.json()
        title_info_list = process_titles_data(genre_id, summary_data)
        df = pd.DataFrame.from_records(title_info_list)

        if not df.empty:
            csv_foldername = "csv_files"
            if not os.path.isdir(csv_foldername):
                os.makedirs(csv_foldername)
                
            csv_filename = os.path.join(
                csv_foldername, 
                f"netflix_movies_from_{from_ix}to{to_ix}.csv"
            )

            with open(f"{csv_filename.replace('.csv', '.json')}", 'w') as fi:
                json.dump(title_info_list, fi)
                
            df.to_csv(csv_filename, index=False)
            print(f"CSV file: {csv_filename} saved successfully!")
            return df
        else:
            print("nothing to save...")
            return
            
    else:
        print("failed to get data. Input correct Netflix Id or check on with correct genre_id and index")

# %%
df = main()
# Out:
# fetch status code --> 200
# processing title 1002: id -> 80082739
# processing title 1003: id -> 80131194
# processing title 1004: id -> 80200957
# processing title 1005: id -> 80013872
# processing title 1006: id -> 81713120
# processing title 1007: id -> 81023618
# processing title 1008: id -> 81329041
# processing title 1009: id -> 81591165
# processing title 1010: id -> 70295741
# processing title 1011: id -> 81050375
# processing title 1012: id -> 81026327
# processing title 1013: id -> 81370442
# processing title 1014: id -> 81678777
# processing title 1015: id -> 60033290
# processing title 1016: id -> 81341143
# processing title 1017: id -> 80117458
# processing title 1018: id -> 80067522
# processing title 1019: id -> 81599072
# processing title 1020: id -> 80240904
# processing title 1021: id -> 80099083
# processing title 1022: id -> 81405851
# processing title 1023: id -> 81270771
# processing title 1024: id -> 80234491
# processing title 1025: id -> 81450779
# processing title 1026: id -> 81154456
# processing title 1027: id -> 81180562
# processing title 1028: id -> 70242570
# processing title 1029: id -> 81245830
# processing title 1030: id -> 80115102
# processing title 1031: id -> 80159955
# processing title 1032: id -> 81289660
# processing title 1033: id -> 81468397
# processing title 1034: id -> 81289069
# processing title 1035: id -> 80244782
# processing title 1036: id -> 81320168
# processing title 1037: id -> 80223050
# processing title 1038: id -> 81516046
# processing title 1039: id -> 60000724
# processing title 1040: id -> 81476857
# processing title 1041: id -> 70099614
# processing title 1042: id -> 81437559
# processing title 1043: id -> 81486147
# processing title 1044: id -> 80223997
# processing title 1045: id -> 80085439
# processing title 1046: id -> 80085438
# processing title 1047: id -> 81003981
# processing title 1048: id -> 80142474
# processing title 1049: id -> 81058434
# processing title 1050: id -> 81001412
# processing title 1051: id -> 81001413
# processing title 1052: id -> 81438157
# processing title 1053: id -> 81498379
# processing title 1054: id -> 81580846
# processing title 1055: id -> 81306350
# processing title 1056: id -> 81600604
# processing title 1057: id -> 70262786
# processing title 1058: id -> 81504566
# processing title 1059: id -> 81507743
# processing title 1060: id -> 81227167
# processing title 1061: id -> 81668040
# processing title 1062: id -> 70278990
# processing title 1063: id -> 81068916
# processing title 1064: id -> 80223731
# processing title 1065: id -> 81266981
# processing title 1066: id -> 81266975
# processing title 1067: id -> 80168234
# processing title 1068: id -> 70021643
# processing title 1069: id -> 81075519
# processing title 1070: id -> 81603171
# processing title 1071: id -> 81570254
# processing title 1072: id -> 81035279
# processing title 1073: id -> 81643796
# processing title 1074: id -> 80057278
# processing title 1075: id -> 80196586
# processing title 1076: id -> 70181734
# processing title 1077: id -> 81048780
# processing title 1078: id -> 81151880
# processing title 1079: id -> 80169617
# processing title 1080: id -> 81504462
# processing title 1081: id -> 70170277
# processing title 1082: id -> 80088678
# processing title 1083: id -> 80088679
# processing title 1084: id -> 70140919
# processing title 1085: id -> 81280352
# processing title 1086: id -> 80149259
# processing title 1087: id -> 81449999
# processing title 1088: id -> 81643798
# processing title 1089: id -> 81615045
# processing title 1090: id -> 81318079
# processing title 1091: id -> 81318078
# processing title 1092: id -> 81361117
# processing title 1093: id -> 81093411
# processing title 1094: id -> 81708832
# processing title 1095: id -> 81171871
# processing title 1096: id -> 81362656
# processing title 1097: id -> 81057246
# processing title 1098: id -> 80128722
# processing title 1099: id -> 60002448
# processing title 1100: id -> 80114666
# processing title 1101: id -> 80149258
# processing title 1102: id -> 81312877
# processing title 1103: id -> 81382296
# processing title 1104: id -> 81139775
# processing title 1105: id -> 80019593
# processing title 1106: id -> 81380539
# processing title 1107: id -> 81623713
# processing title 1108: id -> 80177448
# processing title 1109: id -> 81513128
# processing title 1110: id -> 81306156
# processing title 1111: id -> 81088083
# processing title 1112: id -> 81081656
# processing title 1113: id -> 70114497
# processing title 1114: id -> 81029777
# processing title 1115: id -> 81351075
# processing title 1116: id -> 81294132
# processing title 1117: id -> 70276514
# processing title 1118: id -> 70292995
# processing title 1119: id -> 81212487
# processing title 1120: id -> 60000428
# processing title 1121: id -> 81310261
# processing title 1122: id -> 80081987
# processing title 1123: id -> 80198508
# processing title 1124: id -> 81290388
# processing title 1125: id -> 81446276
# processing title 1126: id -> 81478629
# processing title 1127: id -> 81458416
# processing title 1128: id -> 80232279
# processing title 1129: id -> 80241136
# processing title 1130: id -> 81162089
# processing title 1131: id -> 81453541
# processing title 1132: id -> 81597036
# processing title 1133: id -> 81602430
# processing title 1134: id -> 81346062
# processing title 1135: id -> 70297757
# processing title 1136: id -> 11819467
# processing title 1137: id -> 80180376
# processing title 1138: id -> 80180373
# processing title 1139: id -> 80198623
# processing title 1140: id -> 81307048
# processing title 1141: id -> 80988262
# processing title 1142: id -> 81660260
# processing title 1143: id -> 81597242
# processing title 1144: id -> 81659940
# processing title 1145: id -> 81676434
# processing title 1146: id -> 80165851
# processing title 1147: id -> 70305893
# processing title 1148: id -> 81319138
# processing title 1149: id -> 81406319
# processing title 1150: id -> 80998967
# processing title 1151: id -> 81509545
# processing title 1152: id -> 80163263
# processing title 1153: id -> 80991404
# processing title 1154: id -> 70295695
# processing title 1155: id -> 60031247
# processing title 1156: id -> 81408628
# processing title 1157: id -> 81031181
# processing title 1158: id -> 81210431
# processing title 1159: id -> 80990341
# processing title 1160: id -> 80213712
# processing title 1161: id -> 81504698
# processing title 1162: id -> 70044599
# processing title 1163: id -> 80097221
# processing title 1164: id -> 70125231
# processing title 1165: id -> 70267242
# processing title 1166: id -> 81346326
# processing title 1167: id -> 81073643
# processing title 1168: id -> 81197050
# processing title 1169: id -> 81639893
# processing title 1170: id -> 80218455
# processing title 1171: id -> 81037873
# processing title 1172: id -> 81116486
# processing title 1173: id -> 81595555
# processing title 1174: id -> 24012660
# processing title 1175: id -> 80199806
# processing title 1176: id -> 81217737
# processing title 1177: id -> 81292944
# processing title 1178: id -> 80990815
# processing title 1179: id -> 70063017
# processing title 1180: id -> 81643800
# processing title 1181: id -> 81602979
# processing title 1182: id -> 70262455
# processing title 1183: id -> 70303432
# processing title 1184: id -> 81474196
# processing title 1185: id -> 81074140
# processing title 1186: id -> 81229197
# processing title 1187: id -> 80098708
# processing title 1188: id -> 81031929
# processing title 1189: id -> 81198998
# processing title 1190: id -> 81123050
# processing title 1191: id -> 70097577
# processing title 1192: id -> 81552053
# processing title 1193: id -> 80106793
# processing title 1194: id -> 70142823
# processing title 1195: id -> 81049950
# processing title 1196: id -> 80204393
# processing title 1197: id -> 81387787
# processing title 1198: id -> 81418617
# processing title 1199: id -> 80143362
# processing title 1200: id -> 81551312
# processing title 1201: id -> 81578318
# processing title 1202: id -> 80017528
# processing title 1203: id -> 81143239
# processing title 1204: id -> 81259883
# processing title 1205: id -> 81580024
# processing title 1206: id -> 81716867
# processing title 1207: id -> 70302193
# processing title 1208: id -> 81320770
# processing title 1209: id -> 81422831
# processing title 1210: id -> 80231917
# processing title 1211: id -> 81387840
# processing title 1212: id -> 81346322
# processing title 1213: id -> 81423642
# processing title 1214: id -> 80058460
# processing title 1215: id -> 81446038
# processing title 1216: id -> 81324382
# processing title 1217: id -> 80109145
# processing title 1218: id -> 81328829
# processing title 1219: id -> 81416533
# processing title 1220: id -> 81452638
# processing title 1221: id -> 81343173
# processing title 1222: id -> 81597203
# processing title 1223: id -> 81381630
# processing title 1224: id -> 81592910
# processing title 1225: id -> 81623070
# processing title 1226: id -> 81486211
# processing title 1227: id -> 81706809
# processing title 1228: id -> 81504320
# processing title 1229: id -> 81334897
# processing title 1230: id -> 80244973
# processing title 1231: id -> 80084834
# processing title 1232: id -> 81452178
# processing title 1233: id -> 81453968
# processing title 1234: id -> 81663108
# processing title 1235: id -> 81344088
# processing title 1236: id -> 81393720
# processing title 1237: id -> 80192445
# processing title 1238: id -> 81582585
# processing title 1239: id -> 81322579
# processing title 1240: id -> 81304894
# processing title 1241: id -> 81304896
# processing title 1242: id -> 81304897
# processing title 1243: id -> 81304899
# processing title 1244: id -> 81647497
# processing title 1245: id -> 60022924
# processing title 1246: id -> 81217746
# processing title 1247: id -> 80991400
# processing title 1248: id -> 81026705
# processing title 1249: id -> 81092491
# processing title 1250: id -> 81590689
# processing title 1251: id -> 81150180
# processing title 1252: id -> 81071970
# processing title 1253: id -> 80990415
# processing title 1254: id -> 81270692
# processing title 1255: id -> 81231197
# processing title 1256: id -> 81436989
# processing title 1257: id -> 80106791
# processing title 1258: id -> 81520453
# processing title 1259: id -> 80157072
# processing title 1260: id -> 81082317
# processing title 1261: id -> 81034553
# processing title 1262: id -> 80231468
# processing title 1263: id -> 81473656
# processing title 1264: id -> 81033086
# processing title 1265: id -> 81316978
# processing title 1266: id -> 81135444
# processing title 1267: id -> 80162993
# processing title 1268: id -> 80187055
# processing title 1269: id -> 81696795
# processing title 1270: id -> 81414099
# processing title 1271: id -> 81682801
# processing title 1272: id -> 81588296
# processing title 1273: id -> 81013626
# processing title 1274: id -> 81179841
# processing title 1275: id -> 81630998
# processing title 1276: id -> 70254352
# processing title 1277: id -> 81111925
# processing title 1278: id -> 81072979
# processing title 1279: id -> 81060149
# processing title 1280: id -> 81341307
# processing title 1281: id -> 70043240
# processing title 1282: id -> 70053460
# processing title 1283: id -> 70206131
# processing title 1284: id -> 81043135
# processing title 1285: id -> 80038162
# processing title 1286: id -> 70101346
# processing title 1287: id -> 70220028
# processing title 1288: id -> 80048061
# processing title 1289: id -> 80233925
# processing title 1290: id -> 81076114
# processing title 1291: id -> 70138790
# processing title 1292: id -> 81286570
# processing title 1293: id -> 81453003
# processing title 1294: id -> 81399298
# processing title 1295: id -> 80167481
# processing title 1296: id -> 80157798
# processing title 1297: id -> 81590644
# processing title 1298: id -> 81020005
# processing title 1299: id -> 70028883
# processing title 1300: id -> 80245104
# processing title 1301: id -> 609910
# processing title 1302: id -> 60035870
# processing title 1303: id -> 80074065
# processing title 1304: id -> 80073188
# processing title 1305: id -> 81517155
# processing title 1306: id -> 81243745
# processing title 1307: id -> 81643804
# processing title 1308: id -> 80242342
# processing title 1309: id -> 81225962
# processing title 1310: id -> 81393386
# processing title 1311: id -> 81167980
# processing title 1312: id -> 80227090
# processing title 1313: id -> 80175421
# processing title 1314: id -> 80094648
# processing title 1315: id -> 81460514
# processing title 1316: id -> 81477797
# processing title 1317: id -> 81477746
# processing title 1318: id -> 81350429
# processing title 1319: id -> 80100937
# processing title 1320: id -> 80220496
# processing title 1321: id -> 70139071
# processing title 1322: id -> 81120982
# processing title 1323: id -> 81043103
# processing title 1324: id -> 81440771
# processing title 1325: id -> 81426667
# processing title 1326: id -> 80118930
# processing title 1327: id -> 81425123
# processing title 1328: id -> 81025595
# processing title 1329: id -> 80211559
# processing title 1330: id -> 80195049
# processing title 1331: id -> 80099016
# processing title 1332: id -> 81435737
# processing title 1333: id -> 80168079
# processing title 1334: id -> 81467099
# processing title 1335: id -> 81349306
# processing title 1336: id -> 81689060
# processing title 1337: id -> 81671712
# processing title 1338: id -> 81663120
# processing title 1339: id -> 81449010
# processing title 1340: id -> 81281029
# processing title 1341: id -> 81273461
